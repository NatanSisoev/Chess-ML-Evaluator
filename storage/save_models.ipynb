# %% [markdown]
# # Optimized And Fitted Models Storage

# %%
from chess_eval import *

sm = StorageManager()

one_dm = load_dataset("one")
one_full_dm = load_dataset("one_full")
one_full_rd_dm = load_dataset("one_full_rd")

# TODO: save only the optimized versions from notebook 7 with all 3 dataframes

# %% [markdown]
# ***

# %% [markdown]
# ## Ridge

# %% [markdown]
# ### `RDG_one`: `Ridge` with `one` dataframe

# %% [markdown]
# ## `RDG_one_full`: `Ridge` with `one_full` dataframe

# %% [markdown]
# ### `RDG_one_full_rd`: `Ridge` with `one_full_rd` dataframe

# %% [markdown]
# ***

# %% [markdown]
# ## XGBRegressor

# %% [markdown]
# ### `XGB_one`: `XGBRegressor` with `one` dataframe

# %% [markdown]
# ### `XGB_one_full`: `XGBRegressor` with `one_full` dataframe

# %% [markdown]
# ### `XGB_one_full_rd`: `XGBRegressor` with `one_full_rd` dataframe

# %% [markdown]
# ***

# %% [markdown]
# ## KNeighborsRegressor

# %% [markdown]
# ### `KNN_one`: `KNeighborsRegressor` with `one` dataframe

# %% [markdown]
# ### `KNN_one_full`: `KNeighborsRegressor` with `one_full` dataframe

# %% [markdown]
# ### `KNN_one_full_rd`: `KNeighborsRegressor` with `one_full_rd` dataframe

# %% [markdown]
# ***

# %% [markdown]
# ## Extra: GradientBoosting

# %% [markdown]
# ### `GBR_one`: GradientBoosting with `one` dataframe

# %%
grb_one_mm = ModelManager(
    model=GradientBoostingRegressor(random_state=RANDOM_STATE)
)
grb_one_mm.fit(one_dm)  # ~20 seconds
sm.save_model(grb_one_mm, one_dm, "GBR_one")
# Out:
# 'C:\\Users\\natan\\MatCAD\\3\\3.1\\Aprenentatge Computacional\\Chess Evaluations\\models\\GBR_one.pkl'

# %% [markdown]
# ### `GBR_one_full`: GradientBoosting with `one_full` dataframe

# %%
grb_one_full_mm = ModelManager(
    model=GradientBoostingRegressor(random_state=RANDOM_STATE)
)
grb_one_full_mm.fit(one_full_dm)  # ~TODO: time
sm.save_model(grb_one_full_mm, one_full_dm, "GBR_one_full")

# %% [markdown]
# ### `GBR_one_full_rd`: GradientBoosting with `one_full_rd` dataframe

# %%
grb_one_full_rd_mm = ModelManager(
    model=GradientBoostingRegressor(random_state=RANDOM_STATE)
)
grb_one_full_rd_mm.fit(one_full_rd_dm)  # ~TODO: time
sm.save_model(grb_one_full_rd_mm, one_full_rd_dm, "GBR_one_full_rd")

# %% [markdown]
# ***

# %% [markdown]
# ## Extra: MLPRegressor

# %% [markdown]
# ### `MLP_one`: `MLPRegressor` with `one` dataframe

# %%
mlp_one_mm = ModelManager(
    model=MLPRegressor(max_iter=2000, random_state=RANDOM_STATE)
)
mlp_one_mm.fit(one_dm)  # ~23 minutes
sm.save_model(mlp_one_mm, one_dm, "MLP_one")
# Out:
# 'C:\\Users\\natan\\MatCAD\\3\\3.1\\Aprenentatge Computacional\\Chess Evaluations\\models\\mlpr_one.pkl'
