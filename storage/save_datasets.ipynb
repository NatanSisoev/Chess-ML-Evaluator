# %%
from chess_eval import *
sm = StorageManager()

# %% [markdown]
# ### `one`: 1 million (read_size=1_000_000, sample_size=100_000) with all features (82)

# %%
one_dm = DataManager(  # ~2 minutes
    read_size=1_000_000,
    sample_size=100_000,
    transformers=FEATURE_TRANSFORMERS,
)
sm.save_dataset(one_dm, "one", force=True)
# Out:
# 'C:\\Users\\natan\\MatCAD\\3\\3.1\\Aprenentatge Computacional\\Chess Evaluations\\data\\features\\one.pkl'

# %% [markdown]
# ### `one_full`: 1 million full (read_size=1_000_000, frac=1) with all features (82)

# %%
one_full_dm = DataManager(
    read_size=1_000_000,
    frac=1,
    transformers=FEATURE_TRANSFORMERS,
)
sm.save_dataset(one_full_dm, "one_full", force=True)

# %% [markdown]
# ### `one_full_rd`: 1 million full random (read_size=None, sample_size=1_000_000) with all features (82)

# %%
one_full_rd_dm = DataManager(
    read_size=None,
    sample_size=1_000_000,
    transformers=FEATURE_TRANSFORMERS,
)
sm.save_dataset(one_full_rd_dm, "one_full_rd", force=True)

# %% [markdown]
# ### `full`: whole dataset  (read_size=None, frac=1) with all features (82)

# %%
run = False
if run:  # too much, not enough RAM
    full_dm = DataManager(
        read_size=None,
        frac=1,
        transformers=FEATURE_TRANSFORMERS,
    )
    sm.save_dataset(full_dm, "full", force=True)
