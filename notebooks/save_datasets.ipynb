# %%
from chess_eval import *
sm = StorageManager()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from chess_eval import *
#       2 sm = StorageManager()
#
# File ~\MatCAD\3\3.1\Aprenentatge Computacional\Chess Evaluations\chess_eval\__init__.py:4
#       2 from .features import FEATURE_TRANSFORMERS, PieceInfo, PawnStructure, KingSafety, Mobility, Attack, BoardControl, GameInfo
#       3 from .managers import clean, DataManager, ModelManager, MetricsManager, evaluate
# ----> 4 from .storage import StorageManager, load_model, load_dataset
#
# File ~\MatCAD\3\3.1\Aprenentatge Computacional\Chess Evaluations\chess_eval\storage.py:14
#      10 from chess_eval import SAVED_DATASETS_DIR, SAVED_MODELS_DIR
#      11 from chess_eval.managers import DataManager, ModelManager
# ---> 14 class StorageManager:
#      15     """
#      16     Unified storage manager for:
# ...

# %% [markdown]
# ### `full`: whole dataset  (read_size=None, frac=1) with all features (82)

# %%
full_dm = DataManager(
    read_size=None,
    frac=1,
    transformers=FEATURE_TRANSFORMERS,
)
sm.save_dataset(full_dm, "full")

# %% [markdown]
# ### `one`: 1 million (read_size=1_000_000, sample_size=100_000) with all features (82)

# %%
one_dm = DataManager(
    read_size=1_000_000,
    sample_size=100_000,
    transformers=FEATURE_TRANSFORMERS,
)
sm.save_dataset(one_dm, "one")
