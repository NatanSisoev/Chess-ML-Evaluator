# %%
from chess_eval import *
sm = StorageManager()

# %%
sm.list_datasets()
# Out:
#           Name          Shape Notes
# 0          one   [100000, 84]
# 1     one_full   [959693, 84]
# 2  one_full_rd  [1000000, 84]

# %%
sm.list_models()
# Out:
#                        Model    Dataset             Notes
# 0  GradientBoostingRegressor  chessData
# 1  GradientBoostingRegressor  chessData  df: allF_1M_100k
# 2  GradientBoostingRegressor        one

# %%
grb_one_mm, one_dm = load_model("GBR_one")
grb_one_mm.predict(one_dm)
evaluate(grb_one_mm)
# Out:
# array([ -47.47058501,   -0.77201409,   55.22832441, ...,  138.38668289,
#          21.20334933, -135.25016293], shape=(20000,))

# %%
mlpr_one_mm, one_dm = load_model("mlpr_one")
mlpr_one_mm.predict(one_dm)
evaluate(mlpr_one_mm)
# Out:
#             Metric       Value
# 0    Spearman Rank    0.620269
# 1  Accuracy (±200)    0.825600
# 2             RMSE  188.550510
# 3  Accuracy (sign)    0.674750
# 4   Recall (white)    0.820198
# 5   Recall (black)    0.675450
# 6              R^2    0.408145
